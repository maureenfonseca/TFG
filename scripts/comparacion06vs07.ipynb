# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Run this to reload the python file
# %autoreload 2
from utils import *

# %%
df_V06 = pd.read_csv('../GPM/Data/harmonized/69633_gpm.csv')
df_V07 = pd.read_csv('../GPM/Data/harmonized/69633_gpm_v07.csv')

# %%
df_V06 = convert_index(df_V06, 'date')
df_V07 = convert_index(df_V07, 'date')

# %%
plt.figure(figsize=(10,6))
plt.plot(df_V06['pcp'], alpha=0.8, label='v06')
plt.plot(df_V07['pcp'], alpha=0.8, label='v07')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_V06['pcp']-df_V07['pcp'], label='v06-v07')
plt.legend()
plt.show()
